# %%
import pandas as pd

# %%
df = pd.read_csv("Twitter_search_Arauz.csv")
#df['user.created_at'] = pd.to_datetime(df['user.created_at'], format="%a %b %d %H:%M:%S +0000 %Y")
#df_new = df[df['user.created_at']>=time.strftime('%Y-%m-%d %H:%M:%S', time.strptime('Fri Jan 01 06:57:46 +0000 2010','%a %b %d %H:%M:%S +0000 %Y'))]
df_new
# Out:
#                            created_at  favorite_count  \
# 0      Mon Feb 01 06:57:46 +0000 2021               0
# 1      Mon Feb 01 06:57:43 +0000 2021               0
# 2      Mon Feb 01 06:57:22 +0000 2021               0
# 3      Mon Feb 01 06:56:58 +0000 2021               0
# 4      Mon Feb 01 06:56:17 +0000 2021               0
# ...                               ...             ...
# 55910  Sun Jan 24 11:14:35 +0000 2021               0
# 55911  Sun Jan 24 11:12:50 +0000 2021               0
# 55912  Sun Jan 24 11:11:47 +0000 2021               0
# 55913  Sun Jan 24 11:11:10 +0000 2021               0
# 55914  Sun Jan 24 11:09:43 +0000 2021               0
#
#                                                full_text               id_str  \
# 0      RT @ecuarauz: Me reuní con @groninty, joven ci...  1356134630609575937
# 1      RT @callimanta: @pabelml @ecuarauz @rabascallc...  1356134617015844867
# 2      RT @eluniversocom: Revista Semana sostiene que...  1356134531414315008
# ...
